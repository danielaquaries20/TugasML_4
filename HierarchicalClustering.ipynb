# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaquaries20/TugasML_4/blob/main/HierarchicalClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, metric = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

# %%
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

X_test = np.array([[15, 39], [81, 80], [30, 45], [75, 15], [100, 50]])

y_test_pred = hc.fit_predict(X_test)

print("Test Data Points and their Predicted Clusters:")
for i in range(len(X_test)):
  print(f"Data Point: {X_test[i]}, Predicted Cluster: {y_test_pred[i] + 1}")


plt.figure()
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')

plt.scatter(X_test[y_test_pred == 0, 0], X_test[y_test_pred == 0, 1], s = 200, c = 'black', marker='*', label = 'Test Cluster 1')
plt.scatter(X_test[y_test_pred == 1, 0], X_test[y_test_pred == 1, 1], s = 200, c = 'black', marker='*', label = 'Test Cluster 2')
plt.scatter(X_test[y_test_pred == 2, 0], X_test[y_test_pred == 2, 1], s = 200, c = 'black', marker='*', label = 'Test Cluster 3')
plt.scatter(X_test[y_test_pred == 3, 0], X_test[y_test_pred == 3, 1], s = 200, c = 'black', marker='*', label = 'Test Cluster 4')
plt.scatter(X_test[y_test_pred == 4, 0], X_test[y_test_pred == 4, 1], s = 200, c = 'black', marker='*', label = 'Test Cluster 5')


plt.title('Clusters of customers with Test Data')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# Test Data Points and their Predicted Clusters:
# Data Point: [15 39], Predicted Cluster: 5
# Data Point: [81 80], Predicted Cluster: 4
# Data Point: [30 45], Predicted Cluster: 2
# Data Point: [75 15], Predicted Cluster: 3
# Data Point: [100  50], Predicted Cluster: 1
