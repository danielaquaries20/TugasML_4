# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaquaries20/TugasML_4/blob/main/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data.csv', usecols=['horsepower', 'price'])

# %%
df.head()
# Out:
#    horsepower    price
# 0       111.0  13495.0
# 1       111.0  16500.0
# 2       154.0  16500.0
# 3       102.0  13950.0
# 4       115.0  17450.0

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   horsepower  200 non-null    float64
#  1   price       200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        horsepower         price
# count  200.000000    200.000000
# mean   103.320000  13230.375000
# std     37.468615   7960.155239
# min     48.000000   5118.000000
# 25%     70.000000   7775.000000
# 50%     95.000000  10320.000000
# 75%    116.000000  16500.750000
# max    262.000000  45400.000000

# %%
df.isnull().sum()
# Out:
# horsepower    0
# price         0
# dtype: int64

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['horsepower'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['horsepower'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['price'].plot(kind='kde', c='g')

f.add_subplot(1,2,2)
plt.boxplot(df['price'])
plt.show()

# %%
plt.scatter(df['horsepower'], df['price'])
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Scatter Plot Horsepower vs Price')
plt.show()

# %%
df.corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.811097
# price         0.811097  1.000000

# %%
df.head()
# Out:
#    horsepower    price
# 0       111.0  13495.0
# 1       111.0  16500.0
# 2       154.0  16500.0
# 3       102.0  13950.0
# 4       115.0  17450.0

# %%
x = df['horsepower'].values.reshape(-1,1)
y = df['price'].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [[162.48047682]]
# [-3984.47872682]

# %%
lin_reg.score(x_test, y_test)
# Out:
# 0.6621365313253005

# %%
y_prediksi = lin_reg.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, y_prediksi, c='r')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Plot Horsepower vs Price')
# Out:
# Text(0.5, 1.0, 'Plot Horsepower vs Price')

# %%
lin_reg.predict([[100]])
# Out:
# array([[12263.5689553]])

# %%
lin_reg.predict([[150]])
# Out:
# array([[20387.59279636]])

# %%
lin_reg.predict([[200]])
# Out:
# array([[28511.61663742]])

# %%
lin_reg.predict([[1000]])
# Out:
# array([[158495.99809436]])
